# %%
import pandas as pd
import numpy as np

from sklearn.feature_selection import VarianceThreshold, mutual_info_regression
from sklearn.linear_model import LassoCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import TimeSeriesSplit

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\USER\\OneDrive - Efrei\\Documents\\Cours MSE\\file rouge\\fil_rouge-etude_chomage_france\\src\\data'

# %%
# Chargement
df = pd.read_csv("../../data/processed/02_dataset_clean.csv")

# Date
df["date"] = pd.to_datetime(df["date"], errors="coerce")
df = df.sort_values("date").reset_index(drop=True)

df.shape
TARGET = "taux_chomage_insee"

X = df.drop(columns=[TARGET, "date"])
y = df[TARGET]

X.shape, y.shape

X_imp = X.fillna(X.median())
y_imp = y.fillna(y.median())
mi = mutual_info_regression(X_imp, y_imp, random_state=42)

# %%
from sklearn.feature_selection import mutual_info_regression

mi = mutual_info_regression(X_imp, y_imp, random_state=42)
mi_rank = (
    pd.Series(mi, index=X.columns)
    .sort_values(ascending=False)
)

mi_rank
# Out:
# population_active                       3.057683
# annee                                   3.038432
# pib                                     2.518595
# ict                                     2.301545
# demandeur_femme_abcd_plus50             2.226202
# demandeur_total_abcd_plus50             2.009939
# demandeur_homme_abcd_plus50             1.843427
# taux_euribor_3m                         1.779615
# demandeur_total_abcd_total              1.733960
# demandeur_homme_abcd_total              1.680718
# demandeur_femme_abcd_total              1.611254
# taux_chomage_ocde                       1.572619
# demandeur_total_abcd_2549               1.569867
# demandeur_homme_abcd_2549               1.549181
# MRO                                     1.513115
# demandeur_femme_abcd_2549               1.459089
# demandeur_total_abcd_moins25            1.426927
# demandeur_femme_abcd_moins25            1.422922
# demandeur_homme_abcd_moins25            1.188157
# nb_interimaires                         0.935108
# isj                                     0.932451
# ipc                                     0.806184
# ipc_energie_only                        0.729248
# indicateur_climat_emploi                0.705619
# indicateur_climat_affaires              0.515996
# nb_defaillances_entreprise              0.508549
# indicateur_retournement_conjoncturel    0.501739
# nb_offres_france_travail                0.283166
# trimestre                               0.000000
# mois                                    0.000000
# dtype: float64
